# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# ![image.png](attachment:1aec05bd-f082-40c6-9271-dc698b928b49.png)

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![image.png](attachment:aecad2c3-74d9-43ef-9f2c-9c480b583a2a.png)

# %% [markdown]
# In this note, Data Science and Ecosystems are summarized.

# %% [markdown]
# ![image.png](attachment:e9d82b82-fbee-4191-9d57-a067eaf44817.png)

# %% [markdown]
# ***Objectives***
# * There are many popular languages that Data Scientists use but the most popular is Python while R has become the world's largest repository of the statistical knowledge.
#
# * There are many libraries used by Data Scientists and they have different functions such as Pandas for data structures and tools, matplotlib for plots and graphs.
#
# * There open-source tools that Data Scientists use such as Jupyter Notebook and Jupyter Lab, R Studio, and Github.

# %% [markdown]
# ![image.png](attachment:cb8bb511-224e-4874-982e-01f8dd2bd8c8.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. Julia
# 3. C++
# 4. C
# 5. Java
# 6. R
# 7. sql
# 8. scala

# %% [markdown]
# ![image.png](attachment:dca385b4-d8de-4f96-9ed8-fa9ae41f166a.png)

# %% [markdown]
# Some of the commonly libraries used by Data Scientists include:
# 1. Pandas (Data Structures and Tools)
# 2. Numpy (Arrays and Matrices)
# 3. Matplotlib (plots and graphs, most popular)
# 4. Seaborn (plots: heat maps, time series, violin plots)
# 5. Scikit-Learn (Machine learning: regression, classification, clustering)
# 6. Keras (Deep Learning Neural Networks)
# 7. TensorFlow (Deep Learning: Production and Deployment)
# 8. PyTorch (Deep Learning: Regression, Classification)

# %% [markdown]
# ![image.png](attachment:394389bf-7688-4bb8-a6cd-5fbbf5893ecc.png)

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |Jupyter Notebook and Jupyterlab|
# |R Studio|
# |Github|

# %% [markdown]
# ![image.png](attachment:9d5f7a72-5ea8-403a-965d-a00130d3696d.png)

# %% [markdown]
# ###Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# ![image.png](attachment:e85971b3-6465-4c7b-845e-7e6c3b5dce8f.png)

# %%
(3*4)+5
#this simple arithmetic expression illustrates multiplication and addition
# Out:
# 17

# %% [markdown]
# ![image.png](attachment:929d8e08-5b19-44a9-b35d-7538c37e4c5c.png)

# %%
200/60
#This will convert 200 minutes to hours by dividing by 60.
# Out:
# 3.3333333333333335

# %% [markdown]
# ![image.png](attachment:bf06e946-5d1b-4a0c-aed6-43ea113de619.png)

# %% [markdown]
# ## Author
# Armie Eloisa Exporna
